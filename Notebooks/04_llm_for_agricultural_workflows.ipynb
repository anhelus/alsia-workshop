# %% [markdown]
# <a href="https://colab.research.google.com/github/anhelus/alsia-workshop/blob/master/Notebooks/llm_for_agricultural_workflows.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LLMs for Agricultural Workflows
# Benvenuti nel notebook di accompagnamento per il talk LLMs for Agricultural Workflows! In questo notebook, vedremo insieme come ...

# %% [markdown]
# # Introduzione
# - Introduzione agli LLM, prompt, contesto...
# - Casi d'uso degli LLM in workflow agricoli
#     - Supporto nella pianificazione delle acquisizioni
#     - Reportistica
#     - Analisi dei report
#     - Caratterizzazione delle analisi
# - Panoramica dei modelli esistenti (privati vs open)

# %% [markdown]
# # Setup dei modelli open

# %% [markdown]
# # Confronto tra esempi di base

# %% [markdown]
# # Prompt engineering

# %% [markdown]
# # Integrazione del contesto

# %% [markdown]
# # Richiesta di output strutturato

# %% [markdown]
# # Agenti (?)
