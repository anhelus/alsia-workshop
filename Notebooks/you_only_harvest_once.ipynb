# %% [markdown]
# <a href="https://colab.research.google.com/github/anhelus/alsia-workshop/blob/master/You_Only_Harvest_Once.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # You Only Harvest Once
#
# Benvenuti nel notebook di accompagnamento per il talk *You Only Harvest Once*! In questo notebook, vedremo insieme come configurare il nostro ambiente di sviluppo, definire dei prompt da passare ad un modello, e via dicendo.

# %%
pip install ultralytics
