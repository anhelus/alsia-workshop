# %% [markdown]
# <a href="https://colab.research.google.com/github/anhelus/alsia-workshop/blob/master/ai_assisted_labeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AI-assisted Labeling
# Benvenuti nel notebook di accompagnamento per il talk AI-Assisted Labeling! In questo notebook, vedremo insieme come configurare il nostro ambiente di sviluppo, effettuare una pre-annotazione semantica con modelli fondazionali e importare questi dati in Label Studio per una rifinitura manuale.

# %% [markdown]
# # Introduzione
# - Utilità dell'AI nell'agricoltura di precisione
# - Modelli esistenti per task di detection
# - Necessità dei dati per il fine-tuning
# - Etichettatura assistita da modelli fondazionali

# %% [markdown]
# # Setup

# %% [markdown]
# # Pre-Annotazione

# %% [markdown]
# - Predizione
# - Salvataggio

# %% [markdown]
# # Importazione in Label Studio
# - Conversione YOLO-LS
# - Caricamento su LS

# %% [markdown]
# # Rifinitura Manuale
